# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd 
df = pd.read_csv('Task_Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
# Time	
df1 = df

# %%
df1['Driving_experience'] = df1['Driving_experience'].str.replace('yr', ' ')
df1['Driving_experience'] = df1['Driving_experience'].str.replace('Above', ' ')

# %%
df1['Driving_experience']
# Out:
# 0         1-2
# 1          10
# 2         1-2
# 3        5-10
# 4         2-5
#          ...
# 12311     2-5
# 12312    5-10
# 12313    5-10
# 12314      10
# 12315    5-10
# Name: Driving_experience, Length: 12316, dtype: object

# %%
df1['Service_year_of_vehicle'] = df1['Service_year_of_vehicle'].str.replace('yr', ' ')
df1['Service_year_of_vehicle'] = df1['Service_year_of_vehicle'].str.replace('Above', ' ')
df1['Service_year_of_vehicle'] = df1['Service_year_of_vehicle'].str.replace('s', ' ')

# %%
df1['Service_year_of_vehicle']
# Out:
# 0           10
# 1        5-10
# 2           NaN
# 3           NaN
# 4        5-10
#           ...
# 12311       NaN
# 12312       NaN
# 12313     2-5
# 12314     2-5
# 12315     2-5
# Name: Service_year_of_vehicle, Length: 12316, dtype: object

# %%
df1['Age_band_of_casualty']
# Out:
# 0           na
# 1           na
# 2        31-50
# 3        18-30
# 4           na
#          ...
# 12311       na
# 12312       na
# 12313    31-50
# 12314       na
# 12315        5
# Name: Age_band_of_casualty, Length: 12316, dtype: object

# %%
df1['Educational_level'].fillna(df1['Educational_level'].mode()[0], inplace=True)
df1['Vehicle_driver_relation'].fillna(df1['Vehicle_driver_relation'].mode()[0], inplace=True)
df1['Driving_experience'].fillna(df1['Driving_experience'].mode()[0], inplace=True)
df1['Type_of_vehicle'].fillna(df1['Type_of_vehicle'].mode()[0], inplace=True)
df1['Owner_of_vehicle'].fillna(df1['Owner_of_vehicle'].mode()[0], inplace=True)
df1['Service_year_of_vehicle'].fillna(df1['Service_year_of_vehicle'].mode()[0], inplace=True)
df1['Vehicle_movement'].fillna(df1['Vehicle_movement'].mode()[0], inplace=True)
df1['Casualty_severity'].fillna(df1['Casualty_severity'].mode()[0], inplace=True)
df1['Work_of_casuality'].fillna(df1['Work_of_casuality'].mode()[0], inplace=True)
df1['Fitness_of_casuality'].fillna(df1['Fitness_of_casuality'].mode()[0], inplace=True)
df1['Defect_of_vehicle'].fillna(df1['Defect_of_vehicle'].mode()[0], inplace=True)
df1['Area_accident_occured'].fillna(df1['Area_accident_occured'].mode()[0], inplace=True)
df1['Lanes_or_Medians'].fillna(df1['Lanes_or_Medians'].mode()[0], inplace=True)
df1['Road_allignment'].fillna(df1['Road_allignment'].mode()[0], inplace=True)
df1['Types_of_Junction'].fillna(df1['Types_of_Junction'].mode()[0], inplace=True)
df1['Road_surface_type'].fillna(df1['Road_surface_type'].mode()[0], inplace=True)
df1['Type_of_collision'].fillna(df1['Type_of_collision'].mode()[0], inplace=True)

# %%
df1.sample(50)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 11491  20:17:00    Thursday              31-50          Male
# 11774  21:15:00    Thursday              18-30          Male
# 11246  18:30:00      Friday              18-30          Male
# 9068   16:25:00      Sunday              18-30          Male
# 4543   18:43:00   Wednesday            Over 51          Male
# 2122   22:15:00      Friday              18-30       Unknown
# 338    17:46:00    Thursday            Over 51          Male
# 4459    9:23:00      Sunday              31-50          Male
# 5160   15:10:00    Saturday              31-50          Male
# 2327   11:25:00      Friday            Unknown          Male
# 1391    8:50:00      Friday              18-30          Male
# 6145   10:53:00    Saturday              31-50          Male
# 5744   22:20:00    Thursday            Over 51          Male
# 5803   17:50:00      Friday              18-30          Male
# ...

# %%
df1['Casualty_severity'] = df1['Casualty_severity'].str.replace('na', df1['Casualty_severity'].mode()[0])
df1['Casualty_class'] = df1['Casualty_class'].str.replace('na', df1['Casualty_class'].mode()[0])
df1['Age_band_of_casualty'] = df1['Age_band_of_casualty'].str.replace('na', df1['Age_band_of_casualty'].mode()[0])
df1['Sex_of_casualty'] = df1['Sex_of_casualty'].str.replace('na', df1['Sex_of_casualty'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df1.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
def remove_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1 
    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR

    return df[(df[column]>= lower_bound) & (df[column]<= upper_bound)]

# %%
df1 = remove_outliers(df1, 'Number_of_vehicles_involved')
remove_outliers(df1, 'Number_of_casualties')
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee               1-2
# 1      Junior high school                Employee                10
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df1.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df1.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee               1-2            Automobile
# 1                Employee                10   Public (> 45 seats)
# 2                Employee               1-2       Lorry (41?100Q)
# 3                Employee              5-10   Public (> 45 seats)
# 4                Employee               2-5            Automobile
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df1.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
num_corr = df1.select_dtypes(include='number')
num_corr = num_corr.corr()
print(num_corr)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(num_corr, annot = True)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df1, x='Sex_of_driver', y ='Number_of_casualties')
plt.title('Relationships between Sex_of_driver and Number_of_casualties')
plt.xlabel('Sex_of_driver')
plt.ylabel('Number_of_casualties')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(12,6))
Driving_experience = df1['Driving_experience'].value_counts()
plt.pie(Driving_experience, labels=Driving_experience.index, autopct='%0.1f%%')
plt.title('Driving_experience')
plt.show()

# %%
plt.figure(figsize=(12,6))
Educational_level = df1['Educational_level'].value_counts()
plt.pie(Educational_level, labels=Educational_level.index, autopct='%0.1f%%')
plt.title('Educational_level')
plt.show()

# %%
plt.figure(figsize=(25,20))
Cause_of_accident = df1['Cause_of_accident'].value_counts()
plt.pie(Cause_of_accident, labels=Cause_of_accident.index, autopct='%0.1f%%')
plt.title('Cause_of_accident')
plt.show()

# %%
plt.figure(figsize=(30,5))
sns.histplot(data=df1, x='Type_of_vehicle', y ='Number_of_vehicles_involved')
plt.title('Relationships between Type_of_vehicle and Number_of_vehicles_involved')
plt.xlabel('Type_of_vehicle')
plt.ylabel('Number_of_vehicles_involved')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# Conclusions:
# 1- most accidents were caused by people who have 5-10 year of driving experience
# 2- majority of drivers were Junior high school

# %% [markdown]
# 1- most accidents were caused by people who have 5-10 year of driving experience

# %% [markdown]
# 2- majority of drivers were Junior high school

# %% [markdown]
# 3- more than a have of the driver's sex of the Number of casualties were men
